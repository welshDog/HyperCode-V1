# %%
# hypercode/research/notebooks/neurodivergent_analysis.ipynb
"""
# Neurodivergent Code Analysis

This notebook demonstrates how to analyze code patterns for different neurodivergent profiles using the HyperCode research framework.

## Setup
```python
import sys
from pathlib import Path

# Add project root to path
project_root = str(Path().absolute().parent.parent)
if project_root not in sys.path:
    sys.path.append(project_root)

from hypercode.research.config import config
from hypercode.research.data.collector import ResearchDataCollector
from hypercode.research.visualization.neuro_visualizer import NeuroVisualizer

# Initialize components
collector = ResearchDataCollector("path/to/hypercode/database.json")
visualizer = NeuroVisualizer(theme="high_contrast")
